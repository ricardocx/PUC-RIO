# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardocx/PUC-RIO/blob/main/MVP_1_Global_AI_Job.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVP Análise de Dados e Boas Práticas
# ## Global AI Job Market & Salary Trends 2025 EDA
# ### A Comprehensive Analysis of Global Employment Trends in Artificial Intelligence
#
# **Nome:** Ricardo Cortez Xavier
#
# **Matrícula:** 4052025000912

# %% [markdown]
# #### Dataset Overview
# This dataset offers a comprehensive analysis of the artificial intelligence job market, featuring over 15,000 real job postings collected from globally accessible employment platforms. The information includes detailed insights into job roles, salaries, and market trends, segmented by country, experience level, and company size, enabling a deep and comparative understanding of global employment trends in the artificial intelligence.
#
# [AI Job Market Analysis Dataset 2025](https://www.kaggle.com/datasets/bismasajjad/global-ai-job-market-and-salary-trends-2025/data). Retrieved from Kaggle.com

# %% [markdown]
# ##### Data Collection Methodology
# The data was collected and curated by the dataset author through ethical web scraping from major job platforms, including:
# - AngelList
# - Company career pages
# - Glassdoor
# - Indeed
# - LinkedIn Jobs
# - Stack Overflow Jobs

# %% [markdown]
# ##### Columns Description
# | Column | Description | Type |
# | ------ | ----------- | ---- |
# | job_id | Unique identifier for each job posting | String |
# | job_title | Standardized job title | String |
# | salary_usd | Annual salary in USD | Integer |
# | salary_currency | Original salary currency | String |
# | salary_local | Salary in local currency | Float |
# | experience_level | EN (Entry), MI (Mid), SE (Senior), EX (Executive) | String |
# | employment_type | FT (Full-time), PT (Part-time), CT (Contract), FL (Freelance) | String |
# | company_location | Country where company is located | String |
# | company_size | S (Small <50), M (Medium 50-250), L (Large >250) | String |
# | employee_residence | Country where employee resides | String |
# | remote_ratio | 0 (No remote), 50 (Hybrid), 100 (Fully remote) | Integer |
# | required_skills | Top 5 required skills (comma-separated) | String |
# | education_required | Minimum education requirement | String |
# | years_experience | Required years of experience | Integer |
# | industry | Industry sector of the company | String |
# | posting_date | Date when job was posted | Date |
# | application_deadline | Application deadline | Date |
# | job_description_length | Character count of job description | Integer |
# | benefits_score | Numerical score of benefits package (1-10) | Float |

# %% [markdown]
# #### Importing Libraries
# This section lists all the library imports required for analysis and visualization.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading the Data
# This section loads the data and displays the first five rows of the created dataframe

# %%
df_ai_job = pd.read_csv('https://raw.githubusercontent.com/ricardocx/PUC-RIO/refs/heads/main/ai_job_dataset.csv')
df_ai_job.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# 4          Singapore           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2     Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                        Scala, SQL, Linux, Python                PhD
# 4                     MLOps, Java, Tableau, Python             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
# 2                 2   Education   2025-03-18           2025-04-07
# 3                 7  Consulting   2024-12-23           2025-02-24
# 4                 0       Media   2025-04-15           2025-06-23
#
#    job_description_length  benefits_score       company_name
# 0                    1076             5.9    Smart Analytics
# 1                    1268             5.2       TechCorp Inc
# 2                    1974             9.4    Autonomous Tech
# 3                    1345             8.6     Future Systems
# 4                    1989             6.6  Advanced Robotics

# %% [markdown]
# #### Data Analysis
# This section will perform data analysis using graphs of the dataset columns.\
# Hover over graphs to see more details.

# %%
print("--- Dataset Info ---")
print(df_ai_job.info())

print("--- Note: There are no Missing Values in the data ---")
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  15000 non-null  object
#  1   job_title               15000 non-null  object
#  2   salary_usd              15000 non-null  int64
#  3   salary_currency         15000 non-null  object
#  4   experience_level        15000 non-null  object
#  5   employment_type         15000 non-null  object
#  6   company_location        15000 non-null  object
#  7   company_size            15000 non-null  object
#  8   employee_residence      15000 non-null  object
#  9   remote_ratio            15000 non-null  int64
#  10  required_skills         15000 non-null  object
#  11  education_required      15000 non-null  object
#  12  years_experience        15000 non-null  int64
#  13  industry                15000 non-null  object
#  14  posting_date            15000 non-null  object
#  15  application_deadline    15000 non-null  object
#  16  job_description_length  15000 non-null  int64
#  17  benefits_score          15000 non-null  float64
#  18  company_name            15000 non-null  object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 2.2+ MB
# None
# --- Note: There are no Missing Values in the data ---

# %% [markdown]
# ##### Correlation

# %%
# Plotting correlation graph of numerical variables

numerical_columns = df_ai_job.select_dtypes(include=['number']).columns

correlation_matrix = df_ai_job[numerical_columns].corr(method='pearson').round(2)

for i in range(correlation_matrix.shape[0]):
    for j in range(correlation_matrix.shape[1]):
        if j > i:
            correlation_matrix.iloc[i, j] = np.nan

labels = ['Salary (USD)', 'Remote Ratio', 'Years Experience', 'Job Description Length', 'Benefits Score']

fig = px.imshow(correlation_matrix, zmin=0, zmax=1, origin="upper",
                labels=dict(x="Variable", y="Variable", color="Correlation"),
                x=labels,
                y=labels,
                text_auto=True,
                color_continuous_scale='greens',
                color_continuous_midpoint=0,
                title='Correlation Matrix of Numerical Variables')

fig.update_xaxes(tickangle=-45, tickfont=dict(size=12))

fig.update_yaxes(tickangle=0, tickfont=dict(size=12))

fig.update_layout(xaxis_title='', yaxis_title='', width=600, plot_bgcolor="rgba(0,0,0,0)")
fig.update_traces(xgap=1, ygap=1, hoverongaps=False,
                  hovertemplate="X: %{x}<br>Y: %{y}<br>Correlation: %{z}<extra></extra>")

fig.show()

print('--- The chart shows that Years Experience has a good correlation with Salary (USD). ---')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0b36e91e-faae-43c0-ab7b-4901a70c3347" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b36e91e-faae-43c0-ab7b-4901a70c3347")) {                    Plotly.newPlot(                        "0b36e91e-faae-43c0-ab7b-4901a70c3347",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Salary (USD)","Remote Ratio","Years Experience","Job Description Length","Benefits Score"],"y":["Salary (USD)","Remote Ratio","Years Experience","Job Description Length","Benefits Score"],"z":[[1.0,null,null,null,null],[0.01,1.0,null,null,null],[0.74,0.02,1.0,null,null],[-0.01,0.0,-0.01,1.0,null],[0.0,0.0,-0.01,0.01,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"X: %{x}\u003cbr\u003eY: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","hoverongaps":false,"xgap":1,"ygap":1}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2 ...
# --- The chart shows that Years Experience has a good correlation with Salary (USD). ---

# %% [markdown]
# ##### Defining Functions to generate graphs

# %%
# Defining Functions

# Function to generate a bar graph
def plot_bar(df, x, y, title, labels, color, orientation, hovertemplate,
             color_discrete_sequence=px.colors.qualitative.Dark24 ,height=600,
             legend_traceorder='normal'):
    fig = px.bar(df, x=x, y=y, title=title,
                 labels=labels, color=color, orientation=orientation,
                 color_discrete_sequence=color_discrete_sequence)
    fig.update_layout(height=height)
    fig.update_traces(marker_line_color='black', marker_line_width=1.5, opacity=0.8,
                      hovertemplate=hovertemplate)
    fig.update_layout(legend_traceorder=legend_traceorder)
    fig.show()

# Function to generate a histogram graph with categorical order
def plot_histogram_category_orders(df, x, title, color, category_orders,
              labels, xaxis_title, yaxis_title,
              ticktext, tickvals, legend_labels,
              hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>',
              color_discrete_sequence=px.colors.qualitative.Pastel2,
              legend_traceorder='reversed'):
    fig = px.histogram(df, x=x, title=title,
                       color=color, color_discrete_sequence=color_discrete_sequence,
                       category_orders=category_orders,
                       labels=labels)
    fig.update_layout(xaxis_title=xaxis_title, yaxis_title=yaxis_title)
    fig.update_traces(marker_line_color='black', marker_line_width=1.5, opacity=0.7,
                      hovertemplate=hovertemplate)
    fig.update_xaxes(ticktext=ticktext, tickvals=tickvals)
    for trace in fig.data:
        if trace.name in legend_labels:
            trace.name = legend_labels[trace.name]

    fig.update_layout(legend_traceorder=legend_traceorder)
    fig.show()

# Function to generate a pie chart that shows label and percentage at the same time
def plot_pie_special(labels, values, title):
    fig = go.Figure(data=[go.Pie(
        labels=labels,
        values=values,
        textinfo='label', textposition='auto',
        texttemplate='%{label}', showlegend=False,
        marker=dict(
            colors=px.colors.qualitative.Set2,
            line=dict(color='rgba(0,0,0,0)', width=0)
        )
    )])

    fig.update_traces(
        textposition='outside', textfont_size=14
    )

    fig.add_trace(go.Pie(
        labels=labels,
        values=values,
        textinfo='percent',
        hovertemplate='<b>%{label}</b><br>Count: %{value}<br><extra></extra>',
        textposition='inside', textfont_size=14,
        showlegend=False,
        marker=dict(
            colors=px.colors.qualitative.Set2,
            line=dict(color='black', width=0)
        )
    ))

    fig.update_traces(
        textfont_size=14,
        pull=[0.01, 0.01, 0.01, 0.01]
    )

    fig.update_layout(title=title, height=400, width=600)
    fig.show()

# Function to generate a box
def plot_box_(df, x, y, title, labels, color, category_orders,
              ticktext='', tickvals='', legend_labels='',
              with_tick=False, legend_traceorder="normal",
              color_discrete_sequence=px.colors.qualitative.Dark24, height=400):
    if with_tick:
        fig = px.box(df, x=x, y=y, title=title,
                     labels=labels, color=color, category_orders=category_orders,
                     color_discrete_sequence=color_discrete_sequence)
        fig.update_yaxes(ticktext=ticktext, tickvals=tickvals)
        legend_labels=legend_labels
        for trace in fig.data:
            if trace.name in legend_labels:
                trace.name = legend_labels[trace.name]
        fig.update_layout(legend_traceorder=legend_traceorder)
    else:
        fig = px.box(df, x=x, y=y, title=title,
                     labels=labels, color=color, category_orders=category_orders,
                     color_discrete_sequence=color_discrete_sequence)

    fig.update_layout(height=height)
    fig.show()

# %% [markdown]
# ##### Job Title Frequency (job_title)

# %%
# Plotting the Frequency of AI jobs titles

job_title_counts = df_ai_job['job_title'].value_counts().reset_index()
job_title_counts.columns = ['job_title', 'count']

plot_bar(df=job_title_counts, x='count', y='job_title',
         title='Job Title Frequency in AI Jobs',
         labels={'job_title': 'Job Title', 'count': 'Count'},
         color='job_title', orientation='h',
         hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c84cfdd1-5ba2-4d71-a394-86c760c68e5a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c84cfdd1-5ba2-4d71-a394-86c760c68e5a")) {                    Plotly.newPlot(                        "c84cfdd1-5ba2-4d71-a394-86c760c68e5a",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning Researcher","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Machine Learning Researcher","offsetgroup":"Machine Learning Researcher","orientation":"h","showlegend":true,"textposition":"auto","x":[808],"xaxis":"x","y":["Machine Learning Researcher"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Software Engineer","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"AI Software Engineer","offsetgroup":"AI Software Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[784],"xaxis":"x","y":["AI Software Engineer"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Autonomous Systems Engineer","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Autonomous Systems Engineer","offsetgroup":"Autonomous Systems Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[777],"xaxis":"x","y":["Autonomous Systems Engineer"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning Engineer","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Machine Learning Engineer","offsetgroup":"Machine Learning Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[772],"xaxis":"x","y":["Machine Learning Engineer"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Architect","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"AI Architect","offsetgroup":"AI Architect","orientation":"h","showlegend":true,"textposition":"auto","x":[771],"xaxis":"x","y":["AI Architect"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Head of AI","marker":{"color":"#222A2A","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Head of AI","offsetgroup":"Head of AI","orientation":"h","showlegend":true,"textposition":"auto","x":[765],"xaxis":"x","y":["Head of AI"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NLP Engineer","marker":{"color":"#B68100","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"NLP Engineer","offsetgroup":"NLP Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[762],"xaxis":"x","y":["NLP Engineer"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u0 ...

# %% [markdown]
# ##### Distribuition of salaries in AI jobs (salary_usd)

# %%
# Plotting the distribution of salaries in AI jobs

fig = px.histogram(df_ai_job, x='salary_usd', nbins=50, title='Salary Distribution in AI Jobs', marginal='box')
fig.update_layout(xaxis_title='Salary (USD)', yaxis_title='Count')
fig.update_traces(marker_color='green', marker_line_color='black', marker_line_width=1.5, opacity=0.6,
                  hovertemplate='<b>Salary (USD)=%{x}</b><br>Count=%{y}<extra></extra>')
fig.show()

print("--- Note: The salary distribution is highly skewed to the right, indicating that most salaries are below $100,000")
print("          with a few high-paying outliers. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="11439bde-d98b-4278-8ba8-76f7d3f6864c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11439bde-d98b-4278-8ba8-76f7d3f6864c")) {                    Plotly.newPlot(                        "11439bde-d98b-4278-8ba8-76f7d3f6864c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\u003cb\u003eSalary (USD)=%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"green","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[90376,61895,152626,80215,54624,123574,79670,70640,160710,102557,102322,115047,124355,68760,150122,78846,59823,181139,155300,93851,134197,102550,99382,52167,53923,109779,80979,52997,42819,82083,67488,68624,146852,178183,150864,126942,53752,111381,41430,166080,96956,196954,56745,113455,158808,174663,46753,69020,288815,124871,70391,115376,106579,135230,67607,88470,79863,60299,85645,110222,49365,162296,102382,99972,64129,87938,71405,316182,72459,78338,51907,122831,124820,134200,51920,56427,213783,59728,119432,284486,157597,196942,207548,68838,125666,73174,33314,69914,152118,78014,48466,97997,128341,111528,138945,98688,109029,84797,290199,195691,193448,138466,91577,92875,213287,62171,152658,95085,86750,64261,205357,165676,114658,143149,116276,61055,50303,65570,231078,106633,121180,64531,125654,182275,117708,143246,203198,69487,95673,59405,131756,42835,61893,141791,258637,49485,172916,324557,73894,122598,94478,53088,116012,35593,149053,88230,224919,220439,48861,115841,57266,66384,184637,92445,57388,53374,95716,157091,204144,190314,198403,153040,51898,115191,170139,63860,125152,61572,101054,145355,183484,111997,214195,93211,82209,149669,56825,131635,163843,73281,51907,178240,83226,46995,275296,300422,116704,98422,210249,67708,95796,229098,134300,74408,201971,180764,49644,89115,38540,180252,56585,103942,176009,59056,76940,110341,102922,44130,128112,48892,127478,100524,45429,62262,68595,301038,46253,59644,53960,94894,91611,285880,115263,51882,82051,122331,159643,254305,52027,43072,87011,36734,84897,173839,59357,51431,96506,59198,223757,74322,120749,138212,199039,105699,38497,63141,87871,255678,132056,146085,85037,42661,119706,110064,91090,80307,107321,59373,65191,152969,147893,69807,67824,141523,122796,81885,118505,133565,60019,76875,64400,68857,97840,168619,118132,81112,111502,151610,95128,136733,69822,88380,199482,56268,142301,178371,157412,250562,167401,85328,94160,147732,50749,222223,47958,52877,138782,66150,178470,62936,159003,98694,50471,104460,63711,64384,223296,73372,92458,80483,71730,186565,114225,160286,60957,90148,105723,388754,45129,68001,51736,112035,55619,56796,61808,78751,238449,81908,79556,70609,100354,62606,44279,36995,193149,88722,145098,83381,46591,99604,262339,58899,109939,32587,102069,153376,92574,92858,84172,66601,99818,96240,72389,118570,56276,93369,115634,215782,110858,77926,115976,71134,63231,96419,221235,213785,59378,61374,77579,61122,53318,182747,138496,79744,133437,90174,87820,66990,122069,56318,45830,70207,84101,57591,45158,132585,99055,212847,135102,63685,122593,107056,53318,90704,125671,62031,171375,69220,80383,175527,141125,305621,187599,33959,229855,85361,80376,45147,46236,72594,119767,141385,231393,58405,60440,195647,298418,182777,87006,69827,206945,99795,114667,128576,60097,101978,353726,95186,133855,162221,124709,58778,59227,191741,125762,100678,117568,134632,106560,94044,79076,198743,97175,64832,143835,181246,46950,84808,153304,187668,72769,222757,160302,78913,226519,175559,141569,164894,88878,101624,84728,97260,69936,75400,107195,75537,109409,49641,60830,48516,98740,109279,103692,110492,226973,1 ...
# --- Note: The salary distribution is highly skewed to the right, indicating that most salaries are below $100,000
#           with a few high-paying outliers. ---

# %% [markdown]
# ##### Experience Levels Frequency in AI jobs (experience_levels)

# %%
# Plotting the experience level distribution of AI jobs

# Assuming 'EN'=Entry, 'MI'=Mid, 'SE'=Senior, 'EX'=Executive
experience_levels_sorted = ['EN', 'MI', 'SE', 'EX']

plot_histogram_category_orders(df_ai_job, x='experience_level', title='Experience Level Frequency in AI Jobs',
                               color='experience_level', category_orders={'experience_level': experience_levels_sorted},
                               labels={'experience_level': 'Experience Level'},
                               xaxis_title='Experience Level', yaxis_title='Count',
                               ticktext=['Entry', 'Mid', 'Senior', 'Executive'],
                               tickvals=['EN', 'MI', 'SE', 'EX'],
                               legend_labels={'EN': 'Entry', 'MI': 'Mid', 'SE': 'Senior', 'EX': 'Executive'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="676f696f-d0cf-44d4-b089-57f3140ad4bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("676f696f-d0cf-44d4-b089-57f3140ad4bd")) {                    Plotly.newPlot(                        "676f696f-d0cf-44d4-b089-57f3140ad4bd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Entry","offsetgroup":"EN","orientation":"v","showlegend":true,"x":["EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN","EN", ...

# %% [markdown]
# ##### Employment Type Distribuition in AI jobs (employment_type)

# %%
# Plotting the pie chart of employment type distribution in AI jobs

employment_type_counts = df_ai_job['employment_type'].value_counts()
employment_type_counts.index = employment_type_counts.index.map({
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part-time',
    'FT': 'Full-time'
})

plot_pie_special(labels=employment_type_counts.index,
                 values=employment_type_counts.values,
                 title='Employment Type Distribution in AI Jobs')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e37a6fd-4b81-4754-919a-99bb7e49e889" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e37a6fd-4b81-4754-919a-99bb7e49e889")) {                    Plotly.newPlot(                        "6e37a6fd-4b81-4754-919a-99bb7e49e889",                        [{"labels":["Full-time","Freelance","Contract","Part-time"],"marker":{"colors":["rgb(102,194,165)","rgb(252,141,98)","rgb(141,160,203)","rgb(231,138,195)","rgb(166,216,84)","rgb(255,217,47)","rgb(229,196,148)","rgb(179,179,179)"],"line":{"color":"rgba(0,0,0,0)","width":0}},"showlegend":false,"textinfo":"label","textposition":"outside","texttemplate":"%{label}","values":[3812,3758,3721,3709],"type":"pie","textfont":{"size":14},"pull":[0.01,0.01,0.01,0.01]},{"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eCount: %{value}\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Full-time","Freelance","Contract","Part-time"],"marker":{"colors":["rgb(102,194,165)","rgb(252,141,98)","rgb(141,160,203)","rgb(231,138,195)","rgb(166,216,84)","rgb(255,217,47)","rgb(229,196,148)","rgb(179,179,179)"],"line":{"color":"black","width":0}},"showlegend":false,"textfont":{"size":14},"textinfo":"percent","textposition":"inside","values":[3812,3758,3721,3709],"type":"pie","pull":[0.01,0.01,0.01,0.01]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# ##### Company Location Frequency in AI jobs (company_location)

# %%
# Plotting the frequency AI ​​company location

company_location_counts = df_ai_job['company_location'].value_counts().reset_index()
company_location_counts.columns = ['company_location', 'count']

plot_bar(df=company_location_counts, x='count', y='company_location',
         title='Company Location Frequency in AI jobs',
         labels={'company_location': 'Company Location', 'count': 'Count'},
         color='company_location', orientation='h',
         hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')

print("--- Note: Germany and Denmark are the countries with the largest number of vacancies in AI, ahead of China and the United States. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9f91279-191d-4ec3-a6b7-54e83a5911d5" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9f91279-191d-4ec3-a6b7-54e83a5911d5")) {                    Plotly.newPlot(                        "e9f91279-191d-4ec3-a6b7-54e83a5911d5",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"textposition":"auto","x":[814],"xaxis":"x","y":["Germany"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Denmark","offsetgroup":"Denmark","orientation":"h","showlegend":true,"textposition":"auto","x":[778],"xaxis":"x","y":["Denmark"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[769],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"France","offsetgroup":"France","orientation":"h","showlegend":true,"textposition":"auto","x":[769],"xaxis":"x","y":["France"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Austria","offsetgroup":"Austria","orientation":"h","showlegend":true,"textposition":"auto","x":[765],"xaxis":"x","y":["Austria"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Singapore","marker":{"color":"#222A2A","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Singapore","offsetgroup":"Singapore","orientation":"h","showlegend":true,"textposition":"auto","x":[764],"xaxis":"x","y":["Singapore"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#B68100","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[763],"xaxis":"x","y":["China"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#750D86","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[754],"xaxis":"x","y":["India"],"yaxis":"y","type":" ...
# --- Note: Germany and Denmark are the countries with the largest number of vacancies in AI, ahead of China and the United States. ---

# %% [markdown]
# ##### Company Size Frequency in AI jobs (company_size)

# %%
# Plotting the frequency AI ​​company size

# Assuming 'S'=Small, 'M'=Medium, 'L'=Large
company_size_sorted = ['S', 'M', 'L']

plot_histogram_category_orders(df_ai_job, x='company_size', title='Company Size Frequency in AI jobs',
                               color='company_size', category_orders={'company_size': company_size_sorted},
                               labels={'company_size': 'Company Size'},
                               xaxis_title='Company Size', yaxis_title='Count',
                               ticktext=['Small', 'Medium', 'Large'],
                               tickvals=['S', 'M', 'L'],
                               legend_labels={'S': 'Small', 'M': 'Medium', 'L': 'Large'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ae90f547-5fdd-433e-b20c-4deab42ccdc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae90f547-5fdd-433e-b20c-4deab42ccdc2")) {                    Plotly.newPlot(                        "ae90f547-5fdd-433e-b20c-4deab42ccdc2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"S","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Small","offsetgroup":"S","orientation":"v","showlegend":true,"x":["S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S","S" ...

# %% [markdown]
# ##### Employee Residence Frequency in AI jobs (employee_residence)

# %%
# Plotting the frequency of employee residence in AI jobs

employee_residence_counts = df_ai_job['employee_residence'].value_counts().reset_index()
employee_residence_counts.columns = ['employee_residence', 'count']

plot_bar(df=employee_residence_counts, x='count', y='employee_residence',
         title='Employee Residence Frequency in AI jobs',
         labels={'employee_residence': 'Employee Residence', 'count': 'Count'},
         color='employee_residence', orientation='h',
         hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3eba9a64-5529-4072-9fb5-a1b896b9a87f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eba9a64-5529-4072-9fb5-a1b896b9a87f")) {                    Plotly.newPlot(                        "3eba9a64-5529-4072-9fb5-a1b896b9a87f",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sweden","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Sweden","offsetgroup":"Sweden","orientation":"h","showlegend":true,"textposition":"auto","x":[790],"xaxis":"x","y":["Sweden"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"France","offsetgroup":"France","orientation":"h","showlegend":true,"textposition":"auto","x":[781],"xaxis":"x","y":["France"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Denmark","offsetgroup":"Denmark","orientation":"h","showlegend":true,"textposition":"auto","x":[777],"xaxis":"x","y":["Denmark"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Austria","offsetgroup":"Austria","orientation":"h","showlegend":true,"textposition":"auto","x":[776],"xaxis":"x","y":["Austria"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[772],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#222A2A","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"textposition":"auto","x":[769],"xaxis":"x","y":["Germany"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Korea","marker":{"color":"#B68100","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"South Korea","offsetgroup":"South Korea","orientation":"h","showlegend":true,"textposition":"auto","x":[763],"xaxis":"x","y":["South Korea"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#750D86","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[762],"xaxis":"x","y":["Canada"],"yaxis": ...

# %% [markdown]
# ##### Remote Ratio Distribution in AI jobs (remote_ratio)

# %%
# Plotting the pie chart of remote ratio distribution in AI jobs

remote_ratio_counts = df_ai_job['remote_ratio'].value_counts()

remote_ratio_counts = remote_ratio_counts.reset_index()
remote_ratio_counts.columns = ['remote_ratio', 'count']
remote_ratio_counts['remote_ratio'] = remote_ratio_counts['remote_ratio'].astype(str)
remote_ratio_counts['remote_label'] = remote_ratio_counts['remote_ratio'].map({
    '0': 'No Remote',
    '50': 'Hybrid',
    '100': 'Fully Remote'
})

plot_pie_special(labels=remote_ratio_counts['remote_label'],
                 values=remote_ratio_counts['count'],
                 title='Remote Ratio Distribution in AI Jobs')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b847b5a7-bd9c-40ec-8800-b647841774a8" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b847b5a7-bd9c-40ec-8800-b647841774a8")) {                    Plotly.newPlot(                        "b847b5a7-bd9c-40ec-8800-b647841774a8",                        [{"labels":["No Remote","Hybrid","Fully Remote"],"marker":{"colors":["rgb(102,194,165)","rgb(252,141,98)","rgb(141,160,203)","rgb(231,138,195)","rgb(166,216,84)","rgb(255,217,47)","rgb(229,196,148)","rgb(179,179,179)"],"line":{"color":"rgba(0,0,0,0)","width":0}},"showlegend":false,"textinfo":"label","textposition":"outside","texttemplate":"%{label}","values":[5075,5005,4920],"type":"pie","textfont":{"size":14},"pull":[0.01,0.01,0.01,0.01]},{"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eCount: %{value}\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","labels":["No Remote","Hybrid","Fully Remote"],"marker":{"colors":["rgb(102,194,165)","rgb(252,141,98)","rgb(141,160,203)","rgb(231,138,195)","rgb(166,216,84)","rgb(255,217,47)","rgb(229,196,148)","rgb(179,179,179)"],"line":{"color":"black","width":0}},"showlegend":false,"textfont":{"size":14},"textinfo":"percent","textposition":"inside","values":[5075,5005,4920],"type":"pie","pull":[0.01,0.01,0.01,0.01]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...

# %% [markdown]
# ##### Required Skills Frequency in AI jobs (required_skills)

# %%
# Plotting the Frequency of AI required skills

required_skills_counts = df_ai_job['required_skills'].str.split(', ').explode().value_counts().reset_index()
required_skills_counts.columns = ['skill', 'count']

plot_bar(df=required_skills_counts, x='count', y='skill',
         title='Required Skills Frequency in AI jobs',
         labels={'skill': 'Skill', 'count': 'Count'},
         color='skill', orientation='h',
         height=700, hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')

print("--- Note 1: The Python and SQL languages are the most requested, the surprise for me is that Scala is required more than Java and R. ---")
print("--- Note 2: The TensorFlow and PyTorch packages are quite requested.  ---")
print("--- Note 3: Knowing Kubernetes, Linux and Git opens up many possibilities. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca980d34-8c15-4f01-8abf-502db052542d" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca980d34-8c15-4f01-8abf-502db052542d")) {                    Plotly.newPlot(                        "ca980d34-8c15-4f01-8abf-502db052542d",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[4450],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[3407],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[3022],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kubernetes","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[3009],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scala","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Scala","offsetgroup":"Scala","orientation":"h","showlegend":true,"textposition":"auto","x":[2794],"xaxis":"x","y":["Scala"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PyTorch","marker":{"color":"#222A2A","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"PyTorch","offsetgroup":"PyTorch","orientation":"h","showlegend":true,"textposition":"auto","x":[2777],"xaxis":"x","y":["PyTorch"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Linux","marker":{"color":"#B68100","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Linux","offsetgroup":"Linux","orientation":"h","showlegend":true,"textposition":"auto","x":[2705],"xaxis":"x","y":["Linux"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Git","marker":{"color":"#750D86","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Git","offsetgroup":"Git","orientation":"h","showlegend":true,"textposition":"auto","x":[2631],"xaxis":"x","y":["Git"],"yaxis":"y","type":"bar" ...
# --- Note 1: The Python and SQL languages are the most requested, the surprise for me is that Scala is required more than Java and R. ---
# --- Note 2: The TensorFlow and PyTorch packages are quite requested.  ---
# --- Note 3: Knowing Kubernetes, Linux and Git opens up many possibilities. ---

# %% [markdown]
# ##### Required Education Frequency in AI jobs (education_required)

# %%
# Plotting the distribution of required education in AI jobs

education_required_sorted = ['Associate', 'Bachelor', 'Master', 'PhD']

plot_histogram_category_orders(df_ai_job, x='education_required', title='Required Education Frequency in AI jobs',
                               color='education_required', category_orders={'education_required': education_required_sorted},
                               labels={'education_required': 'Education Required'},
                               xaxis_title='Education Required', yaxis_title='Count',
                               ticktext=['Associate', 'Bachelor', 'Master', 'PhD'],
                               tickvals=['Associate', 'Bachelor', 'Master', 'PhD'],
                               legend_labels={'Associate': 'Associate', 'Bachelor': 'Bachelor', 'Master': 'Master', 'PhD': 'PhD'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a440cc41-b177-4aa8-a738-68ab9a81742e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a440cc41-b177-4aa8-a738-68ab9a81742e")) {                    Plotly.newPlot(                        "a440cc41-b177-4aa8-a738-68ab9a81742e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Associate","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Associate","offsetgroup":"Associate","orientation":"v","showlegend":true,"x":["Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associate","Associ ...

# %% [markdown]
# ##### Years Experience Frequency in AI jobs (years_experience)

# %%
# Plotting the distribution of years of experience in AI jobs

bins = [0, 2, 5, 10, 20]
labels = ['Up to 1', '2-4', '5-9', '10-19']

years_experience_grouped = pd.cut(df_ai_job['years_experience'], bins=bins, labels=labels, right=False)
years_experience_counts = years_experience_grouped.value_counts().sort_index()

plot_bar(df=years_experience_counts, x=years_experience_counts.index, y=years_experience_counts.values,
         title='Years Experience Frequency in AI jobs',
         labels={'x': 'Years Experience', 'y': 'Count', 'years_experience': 'Years Experience'},
         color=years_experience_counts.index, orientation='v',
         color_discrete_sequence=px.colors.qualitative.Pastel1,
         hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>',
         legend_traceorder="reversed")

print("--- Note : There are plenty of vacancies for up to 1 year of experience compared to the other ranges,")
print("           especially if we consider the range from 10 years onwards. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5309d575-6f67-4199-8d01-c17450e6ecbd" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5309d575-6f67-4199-8d01-c17450e6ecbd")) {                    Plotly.newPlot(                        "5309d575-6f67-4199-8d01-c17450e6ecbd",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Up to 1","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Up to 1","offsetgroup":"Up to 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Up to 1"],"xaxis":"x","y":[3718],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2-4","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"2-4","offsetgroup":"2-4","orientation":"v","showlegend":true,"textposition":"auto","x":["2-4"],"xaxis":"x","y":[3781],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5-9","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"5-9","offsetgroup":"5-9","orientation":"v","showlegend":true,"textposition":"auto","x":["5-9"],"xaxis":"x","y":[3741],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10-19","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"10-19","offsetgroup":"10-19","orientation":"v","showlegend":true,"textposition":"auto","x":["10-19"],"xaxis":"x","y":[3760],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"tic ...
# --- Note : There are plenty of vacancies for up to 1 year of experience compared to the other ranges,
#            especially if we consider the range from 10 years onwards. ---

# %% [markdown]
# ##### Industry Frequency in AI jobs (industry)

# %%
# Plotting the distribution of industry in AI jobs

industry_counts = df_ai_job['industry'].value_counts().reset_index()
industry_counts.columns = ['industry', 'count']

plot_bar(df=industry_counts, x='count', y='industry',
         title='Industry Frequency in AI jobs',
         labels={'industry': 'Industry', 'count': 'Count'},
         color='industry', orientation='h',
         hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="80cd8078-52c1-4f3c-96a8-66f8e289b4af" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80cd8078-52c1-4f3c-96a8-66f8e289b4af")) {                    Plotly.newPlot(                        "80cd8078-52c1-4f3c-96a8-66f8e289b4af",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Retail","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Retail","offsetgroup":"Retail","orientation":"h","showlegend":true,"textposition":"auto","x":[1063],"xaxis":"x","y":["Retail"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Media","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Media","offsetgroup":"Media","orientation":"h","showlegend":true,"textposition":"auto","x":[1045],"xaxis":"x","y":["Media"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Automotive","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Automotive","offsetgroup":"Automotive","orientation":"h","showlegend":true,"textposition":"auto","x":[1020],"xaxis":"x","y":["Automotive"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consulting","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Consulting","offsetgroup":"Consulting","orientation":"h","showlegend":true,"textposition":"auto","x":[1020],"xaxis":"x","y":["Consulting"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Technology","offsetgroup":"Technology","orientation":"h","showlegend":true,"textposition":"auto","x":[1011],"xaxis":"x","y":["Technology"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Real Estate","marker":{"color":"#222A2A","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Real Estate","offsetgroup":"Real Estate","orientation":"h","showlegend":true,"textposition":"auto","x":[1007],"xaxis":"x","y":["Real Estate"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Government","marker":{"color":"#B68100","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Government","offsetgroup":"Government","orientation":"h","showlegend":true,"textposition":"auto","x":[998],"xaxis":"x","y":["Government"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transportation","marker":{"color":"#750D86","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Transportation","offsetgroup":"Transportation","orientation":"h","sh ...

# %% [markdown]
# ##### Posting Date frequency over time in AI Job (posting_date)

# %%
# Plotting the frequency of job posting in AI jobs

df_ai_job['posting_date'] = pd.to_datetime(df_ai_job['posting_date'])
posting_date_counts = df_ai_job['posting_date'].dt.to_period('M').value_counts().sort_index()

fig = px.line(posting_date_counts, x=posting_date_counts.index.astype(str), y=posting_date_counts.values, markers=True,
             title='Posting Date frequency over time in AI Job',
             labels={'x': 'Posting Date', 'y': 'Count'}, color_discrete_sequence=px.colors.qualitative.Plotly)
fig.update_layout(xaxis_title='Posting Date', yaxis_title='Count')
fig.update_yaxes(range=[800, None])
fig.update_traces(marker_line_color='black', marker_line_width=1.5,
                  hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>')

fig.add_hline(y=920, line_dash="dash", line_color="blue", opacity=0.5,
              annotation_text="920", annotation_position="left", )

fig.show()
print("--- Note: The graph shows that the frequency of job postings in AI jobs remained above 920 postings ")
print("          and only in Sep 2024 and Feb 2025 the frequency was lower than that. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="748733a2-2ba0-4c72-a74b-787a2a442841" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("748733a2-2ba0-4c72-a74b-787a2a442841")) {                    Plotly.newPlot(                        "748733a2-2ba0-4c72-a74b-787a2a442841",                        [{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle","line":{"color":"black","width":1.5}},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04"],"xaxis":"x","y":[953,927,932,985,955,938,959,958,895,949,922,959,964,840,922,942],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"colo ...
# --- Note: The graph shows that the frequency of job postings in AI jobs remained above 920 postings
#           and only in Sep 2024 and Feb 2025 the frequency was lower than that. ---

# %% [markdown]
# ##### Application Deadline Frequency over time in AI jobs (application_deadline)

# %%
# Plotting the frequency of application deadline in AI jobs

df_ai_job['application_deadline'] = pd.to_datetime(df_ai_job['application_deadline'])

application_deadline_counts = df_ai_job['application_deadline'].dt.to_period('M').value_counts().sort_index()

fig = px.line(application_deadline_counts, x=application_deadline_counts.index.astype(str), y=application_deadline_counts.values, markers=True,
             title='Application Deadline Frequency over time in AI jobs',
             labels={'x': 'Application Deadline', 'y': 'Count'}, color_discrete_sequence=px.colors.qualitative.Plotly)
fig.update_layout(xaxis_title='Application Deadline', yaxis_title='Count')
fig.update_yaxes(range=[0, None])
fig.update_traces(marker_line_color='black', marker_line_width=1.5, opacity=0.7,
                  hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b86611b5-c277-48bd-86b3-9ecae0eec4d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b86611b5-c277-48bd-86b3-9ecae0eec4d1")) {                    Plotly.newPlot(                        "b86611b5-c277-48bd-86b3-9ecae0eec4d1",                        [{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle","line":{"color":"black","width":1.5}},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07"],"xaxis":"x","y":[80,514,921,887,952,965,975,963,905,1001,866,955,959,878,918,918,873,427,43],"yaxis":"y","type":"scatter","opacity":0.7}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...

# %% [markdown]
# ##### Job Description Length Frequency in AI jobs (job_description_length)

# %%
# Plotting the distribution of the character count of job description in AI jobs

bins = [500, 1001, 1501, 2001, 2501]
labels = ['500-1000', '1001-1500', '1501-2000', '2001-2500']

job_description_length_grouped = pd.cut(df_ai_job['job_description_length'], bins=bins, labels=labels, right=False)
job_description_length_counts = job_description_length_grouped.value_counts().sort_index()

plot_bar(df=job_description_length_counts, x=job_description_length_counts.index, y=job_description_length_counts.values,
         title='Job Description Length Frequency in AI jobs',
         labels={'x': 'Job Description Length (characters)', 'y': 'Count', 'job_description_length': 'Job Description Length'},
         color=job_description_length_counts.index, orientation='v',
         color_discrete_sequence=px.colors.qualitative.Pastel1,
         hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>',
         legend_traceorder="reversed")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca6687e4-07cd-44cb-923d-2e6bf8108423" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca6687e4-07cd-44cb-923d-2e6bf8108423")) {                    Plotly.newPlot(                        "ca6687e4-07cd-44cb-923d-2e6bf8108423",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"500-1000","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"500-1000","offsetgroup":"500-1000","orientation":"v","showlegend":true,"textposition":"auto","x":["500-1000"],"xaxis":"x","y":[3729],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1001-1500","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"1001-1500","offsetgroup":"1001-1500","orientation":"v","showlegend":true,"textposition":"auto","x":["1001-1500"],"xaxis":"x","y":[3686],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1501-2000","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"1501-2000","offsetgroup":"1501-2000","orientation":"v","showlegend":true,"textposition":"auto","x":["1501-2000"],"xaxis":"x","y":[3836],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2001-2500","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"2001-2500","offsetgroup":"2001-2500","orientation":"v","showlegend":true,"textposition":"auto","x":["2001-2500"],"xaxis":"x","y":[3749],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"conto ...

# %% [markdown]
# ##### Benefits Score Frequency in AI jobs (benefits_score)

# %%
# Plotting the frequency of benefits package score in AI jobs

bins = [5, 6, 7, 8, 9, 10, 11]
labels=['5-5.9','6-6.9', '7-7.9', '8-8.9', '9-9.9', '10']

benefits_score_grouped = pd.cut(df_ai_job['benefits_score'], bins=bins, labels=labels, right=False)
benefits_score_counts = benefits_score_grouped.value_counts().sort_index()

plot_bar(df=benefits_score_counts, x=benefits_score_counts.index, y=benefits_score_counts.values,
         title='Benefits Score Frequency in AI jobs',
         labels={'x': 'Benefits Score', 'y': 'Count', 'benefits_score': 'Benefits Score'},
         color=benefits_score_counts.index, orientation='v',
         color_discrete_sequence=px.colors.qualitative.Pastel1,
         hovertemplate='<b>%{x}</b><br>Count=%{y}<extra></extra>',
         legend_traceorder="reversed")
print("--- Note: The graph shows the frequency of the score of benefits package in AI jobs, grouped by ranges. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0d4f60de-64c3-4ae5-9ade-a0791fde45b8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d4f60de-64c3-4ae5-9ade-a0791fde45b8")) {                    Plotly.newPlot(                        "0d4f60de-64c3-4ae5-9ade-a0791fde45b8",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5-5.9","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"5-5.9","offsetgroup":"5-5.9","orientation":"v","showlegend":true,"textposition":"auto","x":["5-5.9"],"xaxis":"x","y":[2888],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6-6.9","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"6-6.9","offsetgroup":"6-6.9","orientation":"v","showlegend":true,"textposition":"auto","x":["6-6.9"],"xaxis":"x","y":[2953],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7-7.9","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"7-7.9","offsetgroup":"7-7.9","orientation":"v","showlegend":true,"textposition":"auto","x":["7-7.9"],"xaxis":"x","y":[2960],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8-8.9","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"8-8.9","offsetgroup":"8-8.9","orientation":"v","showlegend":true,"textposition":"auto","x":["8-8.9"],"xaxis":"x","y":[3005],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9-9.9","marker":{"color":"rgb(254,217,166)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"9-9.9","offsetgroup":"9-9.9","orientation":"v","showlegend":true,"textposition":"auto","x":["9-9.9"],"xaxis":"x","y":[3052],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10","marker":{"color":"rgb(255,255,204)","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"10","offsetgroup":"10","orientation":"v","showlegend":true,"textposition":"auto","x":["10"],"xaxis":"x","y":[142],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f ...
# --- Note: The graph shows the frequency of the score of benefits package in AI jobs, grouped by ranges. ---

# %% [markdown]
# #### Questions
# This section will show you some questions about Global AI Job Market & Salary Trends 2025
#
# Note: The data was ordered by the median because it is a robust measure to outliers and is indicated when the data distribution is not symmetric and has a long "tail" to one side, as seen in the salary distribution graph.

# %% [markdown]
# ##### What is the salary distribution vs job title? (ordered by median salary)

# %%
# Plotting the salary distribution by job title (Ordered by median salary)

job_titles_sorted = df_ai_job.groupby("job_title")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='job_title', color='job_title',
          title='Salary Distribution vs Job Title<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'job_title': 'Job Title'},
          category_orders={'job_title': job_titles_sorted}, height=600)

print("--- Note 1: The highest median salaries are for Data Engineer, Machine Learning Engineer and Ai Specialist. ---")
print("--- Note 2: The median salary for the listed job titles from data engineer to data scientist is higher than")
print("            the median salary ($100,000) for the 15,000 jobs analyzed. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a4f708a8-5c58-4a0a-8a45-bb8e9cc77350" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4f708a8-5c58-4a0a-8a45-bb8e9cc77350")) {                    Plotly.newPlot(                        "a4f708a8-5c58-4a0a-8a45-bb8e9cc77350",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Engineer","marker":{"color":"#2E91E5"},"name":"Data Engineer","notched":false,"offsetgroup":"Data Engineer","orientation":"h","showlegend":true,"x":[155300,134197,166080,64129,51920,56427,213287,143246,145355,95796,128112,85037,141523,142301,167401,50471,68001,55619,182747,171375,72594,143835,160302,75400,77042,63273,82918,259184,153083,142309,112920,88916,113269,63073,63479,166340,268001,103620,57729,283569,213979,158240,158973,175244,157394,194442,57458,65948,167739,152069,76655,38483,269645,127936,186582,51089,142412,52448,243337,53562,251827,63771,51671,105434,134019,107501,93566,90189,49276,74684,69734,123064,55042,114270,89494,148785,67354,107552,111536,144386,222945,54678,75428,110941,130323,96291,59023,228323,88152,50287,105387,98156,90770,188284,175297,310349,87139,84133,164421,63425,82441,71084,79605,123539,46459,72143,56366,102104,51569,121559,172560,113181,104611,92791,73709,89375,60074,155086,42538,113896,79925,129595,249105,40107,144698,134875,134413,121792,176004,143661,69080,129484,94744,119490,66780,96755,93573,33951,184567,75628,215030,211143,51753,61495,65806,97541,66794,175868,90683,110583,47563,123578,59701,177470,81264,158957,129438,161860,74951,41658,169467,306264,88707,127102,87821,159055,212905,131232,145082,47933,100978,62047,238935,88655,54421,162913,100193,94493,62906,37356,125119,72491,57980,89094,98267,246407,144032,84000,117991,201600,120407,87328,60632,102794,66712,56686,114960,85114,124142,89060,48428,184808,111135,111477,187388,89423,165951,74226,154618,150472,44161,139450,102931,54304,110554,79911,86941,51745,53290,237736,48705,83080,298913,243831,123068,88100,71674,78614,236928,48211,65987,87456,89037,61792,100812,119752,42201,118205,205500,69708,72279,126322,122517,93102,72360,54707,94160,253381,85663,126687,59797,124633,108212,117427,60379,98259,168953,226528,79653,123850,69059,215337,170391,201147,50902,83280,263099,100715,169386,173805,259802,139487,52539,187618,52032,205495,107305,96759,36579,210002,189578,73109,97773,89600,177150,66477,144658,94472,64382,55859,144869,137404,124141,156494,103464,154560,187920,162807,94197,96832,202187,184155,46310,64638,150046,158788,81215,93794,68107,104155,111787,260042,203293,105738,56196,83974,109351,89555,139216,163893,170767,163939,79810,37053,146336,59368,81833,37602,69590,51723,157103,83312,69851,50229,92239,97775,58988,141799,149691,162134,152442,235424,117720,233158,60780,101087,47073,103559,76845,65785,61707,216814,123743,161413,43768,97808,89765,220287,156656,113492,166159,139759,57854,93524,59947,53084,113428,166806,154236,169188,40265,235948,64475,160721,49653,84056,103035,119694,174266,89294,195522,77204,74210,63911,92558,117557,109139,48516,184388,117200,74497,127768,183349,72123,105986,120900,147015,110512,134512,58514,120757,42386,221447,129326,96465,82610,194929,92756,60525,157188,186106,47095,160596,108792,129688,65812,94796,151387,158991,64601,60920,46798,64275,68553,84140,252220,117610,160583,70029,118941,117988,166059,99773,110498,74674,107762,63398,72410,44300,75147,147252,231445,68220,113243,144585,54511,75218,147558,86554,75361,127005,64254,67580,191397,110055,165369,167732,49827,79135,121523,139300,95560,175458,65169,110342,137450,153939,83137,120435,93342,38208,87807,291966,115632,90932,240515,143016,95801,147094,89214,50055,1 ...
# --- Note 1: The highest median salaries are for Data Engineer, Machine Learning Engineer and Ai Specialist. ---
# --- Note 2: The median salary for the listed job titles from data engineer to data scientist is higher than
#             the median salary ($100,000) for the 15,000 jobs analyzed. ---

# %% [markdown]
# ##### What is the salary distribution vs experience level? (ordered by median salary)

# %%
# Plotting the salary distribution vs experience level (Ordered by median salary)

experience_levels_sorted = df_ai_job.groupby("experience_level")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='experience_level', color='experience_level',
          title='Salary Distribution vs Experience Level<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'experience_level': 'Experience Level'},
          category_orders={'experience_level': experience_levels_sorted},
          ticktext=['Entry', 'Mid', 'Senior', 'Executive'],
          tickvals=['EN', 'MI', 'SE', 'EX'],
          legend_labels={'EN': 'Entry', 'MI': 'Mid', 'SE': 'Senior', 'EX': 'Executive'},
          with_tick=True)

print("--- Note 1: Note: The graph shows the increasing influence of experience level on salary in AI Jobs. ---")
print("--- Note 2: The highest median salaries are for Executive and Senior levels, followed by Mid and Entry levels. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a8dd2679-56e3-49c9-ab6a-597a51007845" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8dd2679-56e3-49c9-ab6a-597a51007845")) {                    Plotly.newPlot(                        "a8dd2679-56e3-49c9-ab6a-597a51007845",                        [{"alignmentgroup":"True","hovertemplate":"Experience Level=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EX","marker":{"color":"#2E91E5"},"name":"Executive","notched":false,"offsetgroup":"EX","orientation":"h","showlegend":true,"x":[115047,181139,178183,126942,111381,166080,288815,124871,115376,316182,213783,284486,157597,196942,207548,125666,152118,138945,290199,138466,213287,152658,205357,165676,231078,182275,143246,95673,141791,258637,324557,149053,224919,220439,184637,190314,198403,145355,183484,214195,178240,275296,300422,210249,95796,229098,134300,201971,180764,301038,285880,254305,223757,138212,199039,255678,110064,152969,141523,168619,199482,142301,178371,157412,250562,167401,147732,222223,138782,178470,159003,98694,186565,160286,388754,238449,193149,99604,262339,153376,93369,215782,115976,221235,213785,182747,133437,132585,135102,171375,141125,305621,187599,229855,141385,231393,298418,206945,353726,95186,124709,191741,125762,134632,198743,187668,222757,160302,226519,97260,109279,226973,170702,149281,152266,217701,138694,146600,156725,272652,134087,188034,146076,142657,291226,271344,136651,237637,135272,160234,286216,259184,105668,223289,153083,201269,148214,313205,111371,120586,182856,139122,162476,160883,138000,261332,133019,216253,169842,167210,303636,115496,224280,349562,137181,151385,242433,116320,102675,222869,195999,236175,145141,149673,204346,184631,113269,231074,193865,154077,203751,221809,174571,283696,233692,100620,104307,201387,150456,106457,176592,237830,210609,114392,145886,168131,222528,146692,137927,169198,122645,262925,169198,188924,87507,152846,145966,268001,132334,153207,283569,173652,154607,213979,202404,192550,135830,189666,144259,202935,200761,272996,149451,231893,122818,194364,128595,98002,178494,154496,166781,206257,145271,133327,308823,249324,165792,349508,95775,128912,324061,264209,193480,278777,171218,162562,192545,194442,215545,178695,91260,114900,267363,206831,260674,161560,211117,156933,203407,243973,197389,161971,117643,152069,172093,145214,179667,171215,156162,187720,334614,237827,269645,135653,149345,264300,268218,244121,128609,177931,199888,139360,283408,155932,184001,306862,171299,109517,161346,272477,139357,133277,152020,133002,220156,291446,122018,370038,191731,164834,243337,121076,175790,202056,97350,219210,190164,101503,191148,134769,307439,153686,289428,185576,164931,302848,251827,232297,304419,158302,270901,233643,364635,165018,224686,175743,283980,93566,197981,144194,139002,237558,129026,160528,229819,200646,168134,183449,157517,201525,175663,289312,131757,227863,162762,203007,186783,289435,131748,146263,128119,172415,275544,171629,193717,156172,275914,211142,154290,361541,178482,316575,156224,211287,201243,159232,144647,102083,223945,206448,197656,139936,175527,224367,305068,201318,146911,163176,161876,131824,148785,312110,119135,127299,270468,105092,87076,159681,106688,142410,266476,217596,236415,263686,172076,111618,179544,100927,266949,221670,228183,258096,104224,267096,111536,101414,144386,231796,166725,129293,151884,183433,215098,241026,219333,144440,253997,166682,185005,179455,147573,268848,150823,96760,91092,101009,158635,239573,249930,290579,173242,244496,187375,238792,226504,186222,151875,331854,240150,219041,163357,208210,159718,161115,270252,185695,127125,186801,133565,223202,180089,193391,184262,284013,86961,174304,273838,145239,160290,161117,209331,91293,136980,2859 ...
# --- Note 1: Note: The graph shows the increasing influence of experience level on salary in AI Jobs. ---
# --- Note 2: The highest median salaries are for Executive and Senior levels, followed by Mid and Entry levels. ---

# %% [markdown]
# ##### What is the salary distribution vs employment type? (ordered by median salary)

# %%
# Plotting the salary distribution vs employment type (Ordered by median salary)

employment_type_sorted = df_ai_job.groupby("employment_type")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='employment_type', color='employment_type',
          title='Salary Distribution vs Employment Type<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'employment_type': 'Employment Type'},
          category_orders={'employment_type': employment_type_sorted},
          ticktext=['Freelance', 'Contract', 'Part-time', 'Full-time'],
          tickvals=['FL', 'CT', 'PT', 'FT'],
          legend_labels={'FL': 'Freelance', 'CT': 'Contract', 'PT': 'Part-time', 'FT': 'Full-time'},
          with_tick=True)

print("--- Note 1: Note: The graph shows that employment type does not have a significant influence on the salary distribution in AI Jobs. ---")
print("--- Note 2: The highest median salaries are for Contract and Full-time employment types, followed by Freelance and Part-time. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86cb77ec-f810-46c0-9e90-56692e56289d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86cb77ec-f810-46c0-9e90-56692e56289d")) {                    Plotly.newPlot(                        "86cb77ec-f810-46c0-9e90-56692e56289d",                        [{"alignmentgroup":"True","hovertemplate":"Employment Type=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CT","marker":{"color":"#2E91E5"},"name":"Contract","notched":false,"offsetgroup":"CT","orientation":"h","showlegend":true,"x":[90376,61895,123574,160710,115047,124355,68760,181139,155300,99382,80979,42819,82083,126942,111381,174663,46753,64129,119432,284486,157597,196942,207548,33314,78014,97997,290199,195691,91577,165676,114658,125654,69487,141791,73894,35593,66384,92445,95716,190314,153040,63860,125152,61572,101054,145355,111997,73281,51907,116704,134300,74408,180764,49644,89115,59056,110341,128112,48892,127478,46253,91611,51882,84897,63141,87871,255678,132056,85037,59373,118505,60019,64400,68857,178371,157412,250562,85328,138782,98694,60957,105723,388754,45129,112035,55619,61808,78751,79556,70609,62606,44279,193149,66601,96240,93369,115976,71134,96419,61374,61122,138496,122069,84101,57591,45158,107056,69220,187599,45147,141385,69827,353726,191741,106560,181246,84808,72769,78913,49641,109279,103692,173054,73669,152266,104315,138694,64826,156725,92035,61352,77636,71473,48920,140113,103806,271344,136651,35782,70013,97749,160234,151942,81319,105668,70084,53116,46556,111371,148848,47999,117075,97771,79627,46796,140104,99041,109969,115496,76339,70128,72448,349562,109757,92318,89020,85887,242433,84450,69485,146370,86410,222869,106477,195999,112920,145141,78123,38010,113269,146154,193865,40586,89120,77360,107828,174571,77553,67912,59027,63073,104307,201387,112934,107490,150456,60806,237830,47919,95469,145886,128378,94183,167929,53057,66276,87507,66992,129418,84718,114575,119161,192550,135830,144259,91619,143704,114323,123019,54256,82655,272996,54146,56145,95030,49933,139174,227312,48962,122818,96120,94589,54488,106704,72245,206257,97247,60462,73640,49643,95775,48201,59904,66124,57458,36197,72300,114900,49496,58108,155456,140234,267363,260674,64003,129423,50135,161971,132548,73263,156162,35049,55411,334614,122233,61681,237827,123571,88770,172697,64393,186582,104706,113645,105008,47668,156235,99360,48541,272477,70997,82330,72552,122100,55463,159438,51089,50111,118816,83896,60737,66901,133002,61729,122018,144518,52448,53562,158284,41740,219210,125594,78867,101503,191148,117815,42268,119558,87169,91405,122643,105825,54500,89986,185576,164931,302848,65630,63771,232297,60252,84414,35937,131769,65792,62143,69399,40622,50086,85175,83412,88025,142753,283980,156040,90189,139002,92965,74684,100235,62450,129026,160528,109273,75728,200646,147780,75958,120068,51178,60646,89198,175663,85205,142913,89500,115817,162762,186783,86969,92941,62950,103040,123064,47244,73307,172415,103322,61256,133978,60900,40719,86032,122390,114270,361541,68838,156224,124105,82260,80733,109585,206448,139936,55445,70693,43632,161876,105881,102801,112517,101245,51083,107022,46498,85954,61379,217596,70149,179544,127134,57968,57458,221670,119356,108600,108379,77973,58188,57574,139398,231796,222945,91566,158916,84294,91668,53064,46475,179455,74385,167289,95710,79221,53844,80355,180474,106248,51215,64872,57458,47257,82455,75428,290579,76495,244496,187375,96466,186222,86278,58030,60749,141332,75735,159718,110941,53572,84479,122851,223202,82405,180089,101381,51764,107417,96291,43233,136980,125319,41569,70984,125758,70196,98487,61132,37133,140278,85861,149846,76070,39939,50892,59023,231990,198321,106404,85502,199683,57514,37774,115486,74426,95706,43498,73979,105675,66340,90830,5 ...
# --- Note 1: Note: The graph shows that employment type does not have a significant influence on the salary distribution in AI Jobs. ---
# --- Note 2: The highest median salaries are for Contract and Full-time employment types, followed by Freelance and Part-time. ---

# %% [markdown]
# ##### What is the salary distribution by company size? (ordered by median salary)

# %%
# Plotting the salary distribution vs company size (Ordered by median salary)

company_size_sorted = df_ai_job.groupby("company_size")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='company_size', color='company_size',
          title='Salary Distribution vs Company Size<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'company_size': 'Company Size'},
          category_orders={'company_size': company_size_sorted},
          ticktext=['Small', 'Medium', 'Large'],
          tickvals=['S', 'M', 'L'],
          legend_labels={'S': 'Small', 'M': 'Medium', 'L': 'Large'},
          with_tick=True)

print("--- Note 1: The graph shows that company size has a positive influence on the wage distribution in AI jobs. ---")
print("--- Note 2: The highest median salaries are for Large companies, followed by Medium and Small companies. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c96801b-cc7c-4313-99a7-c107e81c8bca" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c96801b-cc7c-4313-99a7-c107e81c8bca")) {                    Plotly.newPlot(                        "7c96801b-cc7c-4313-99a7-c107e81c8bca",                        [{"alignmentgroup":"True","hovertemplate":"Company Size=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"L","marker":{"color":"#2E91E5"},"name":"Large","notched":false,"offsetgroup":"L","orientation":"h","showlegend":true,"x":[152626,70640,160710,78846,59823,181139,93851,109779,82083,150864,126942,166080,196954,56745,69020,88470,79863,60299,64129,71405,78338,119432,157597,196942,125666,78014,111528,290199,195691,193448,138466,152658,143149,50303,121180,64531,125654,182275,117708,203198,59405,42835,324557,88230,57388,157091,204144,153040,170139,63860,61572,111997,82209,131635,163843,73281,275296,116704,98422,229098,49644,180252,176009,102922,128112,127478,45429,62262,94894,91611,285880,115263,122331,87011,84897,59357,74322,87871,119706,80307,107321,59373,152969,69807,67824,141523,122796,64400,168619,151610,95128,88380,85328,47958,52877,178470,64384,223296,80483,71730,114225,60957,388754,112035,61808,81908,193149,145098,262339,84172,99818,96240,118570,115634,110858,71134,63231,59378,77579,61122,84101,122593,90704,171375,229855,85361,119767,231393,58405,60440,195647,298418,69827,128576,162221,191741,117568,94044,153304,78913,164894,88878,75400,107195,109409,49641,48516,110492,226973,173054,73669,101933,43707,161796,63866,130454,145190,61289,146600,156725,94680,117510,214326,159755,188034,103806,271344,237637,59160,49162,135272,286216,151942,81319,223289,70084,69418,313205,83357,109917,160078,111371,112595,162476,106583,216253,106332,99041,109969,115496,224280,131250,123728,72448,90172,133372,349562,109757,176838,92318,92317,100729,132294,66066,242433,84450,146370,150795,148341,112920,118402,145141,118524,52062,204346,113269,231074,103963,65442,88616,203751,101302,174571,84547,67912,59027,63073,55576,283696,61847,112261,112934,108067,107490,150456,230849,163009,80463,125444,95469,128378,88058,46224,222528,73953,146692,64885,137927,166340,262925,169198,104981,152846,175737,86453,64180,114575,119161,93743,202404,107720,158240,113684,189666,202935,143704,82655,200761,121384,96311,167621,74676,227312,194364,158973,128247,60149,66901,178494,92213,106704,175244,81533,308823,130424,249324,221853,49643,349508,204850,48201,324061,264209,278777,64705,84494,162562,192545,85110,71765,215545,65948,63655,64687,155456,64577,140234,112489,167739,144276,129423,203407,88118,243973,172307,102396,87052,108338,62406,88746,109131,88423,179667,53379,334614,52483,122233,221710,269645,135653,89557,127936,172697,264300,49695,64393,177931,64276,80426,93366,104706,85510,73796,113645,113621,82405,306862,129639,153539,99360,272477,109453,76023,122100,55463,159438,83896,60737,96170,291446,101711,93842,370038,118612,63842,116906,52801,84698,191681,243337,175790,202056,112811,87243,158284,41740,61301,75430,113607,42732,71698,164439,96277,122274,307439,120739,143215,114706,119558,72092,49096,90597,89986,117816,302848,58841,251827,124148,65630,146156,130564,158302,84414,64590,65792,109449,93165,105434,364635,66172,119439,115552,107501,88025,175743,142753,283980,156040,130884,64816,125867,144194,67449,149802,75728,168134,119685,190447,120068,60646,183449,129483,201525,86918,91777,85205,79684,289312,87273,131757,115817,186783,135743,289435,103040,102678,123064,111672,128119,172415,61256,117819,60900,65473,211142,122390,89494,75304,361541,51565,124105,125538,85696,83339,159232,80733,50634,121271,72800,118220,175527,55445,86027,70693,140451,83330,123371,119135,105881,127299, ...
# --- Note 1: The graph shows that company size has a positive influence on the wage distribution in AI jobs. ---
# --- Note 2: The highest median salaries are for Large companies, followed by Medium and Small companies. ---

# %% [markdown]
# ##### What is the salary distribution vs remote ratio? (ordered by median salary)

# %%
# Plotting the salary distribution vs remote ratio (Ordered by median salary)

remote_ratio_sorted = df_ai_job[["remote_ratio", "salary_usd"]]
remote_ratio_sorted["remote_ratio"] = remote_ratio_sorted["remote_ratio"].astype(str)
remote_ratio_sorted['remote_label'] = remote_ratio_sorted['remote_ratio'].map({
    '0': 'No Remote',
    '50': 'Hybrid',
    '100': 'Fully Remote'
})

remote_ratio_sorted_index = remote_ratio_sorted.groupby("remote_label")["salary_usd"].median().sort_values(ascending=False).reset_index()

plot_box_(remote_ratio_sorted, x='salary_usd', y='remote_label', color='remote_label',
          title='Salary Distribution vs Remote Ratio<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'remote_label': 'Remote Ratio'},
          category_orders={'remote_label': remote_ratio_sorted_index['remote_label'].unique()},
          ticktext=['No Remote', 'Hybrid', 'Fully Remote'],
          tickvals=['No Remote', 'Hybrid', 'Fully Remote'],
          legend_labels={'0': 'No Remote', '50': 'Hybrid', '100': 'Fully Remote'},
          with_tick=True)

print("--- Note: Note: The graph shows that remote ratio does not have a significant influence on the salary distribution in AI Jobs. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f1aa573-c756-45e5-b61b-99489b5bf7a0" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f1aa573-c756-45e5-b61b-99489b5bf7a0")) {                    Plotly.newPlot(                        "5f1aa573-c756-45e5-b61b-99489b5bf7a0",                        [{"alignmentgroup":"True","hovertemplate":"Remote Ratio=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fully Remote","marker":{"color":"#2E91E5"},"name":"Fully Remote","notched":false,"offsetgroup":"Fully Remote","orientation":"h","showlegend":true,"x":[61895,54624,102322,124355,150122,59823,181139,93851,52167,109779,82083,67488,53752,166080,56745,115376,106579,135230,79863,60299,87938,72459,78338,51907,122831,51920,56427,213783,196942,125666,69914,48466,193448,138466,91577,213287,95085,86750,205357,114658,61055,50303,106633,59405,172916,324557,94478,224919,220439,48861,184637,204144,190314,63860,125152,145355,183484,111997,214195,82209,46995,300422,116704,210249,95796,74408,180764,49644,128112,48892,62262,82051,159643,52027,43072,36734,173839,51431,96506,38497,63141,87871,146085,110064,91090,122796,133565,60019,97840,168619,118132,81112,151610,95128,94160,147732,66150,178470,62936,50471,71730,60957,68001,55619,78751,81908,79556,70609,100354,62606,88722,145098,46591,109939,32587,66601,99818,96240,72389,115976,213785,59378,182747,138496,122069,45158,132585,135102,122593,69220,175527,141125,305621,45147,46236,72594,119767,58405,195647,206945,99795,353726,95186,124709,100678,117568,134632,94044,46950,78913,164894,84728,97260,75537,49641,48516,226973,171987,173054,98984,170702,85625,127955,161796,128702,63866,138694,130454,61289,92035,61352,77636,71473,48920,188034,103806,142657,65226,171571,83663,46323,137427,160234,286216,259184,105668,70084,69418,201269,130864,109917,115301,46556,49630,112595,87531,106583,117075,79627,216253,97370,45441,140104,303636,42279,101235,109969,115496,224280,50915,131250,70128,123728,72448,349562,137181,92318,132294,85887,66066,222869,148341,142309,153558,236175,118402,145141,78123,38010,46335,204346,184631,113269,146154,89120,77360,203751,84547,77553,67912,101440,66881,100620,88800,57025,112934,108067,150456,106457,230849,98449,176592,80463,210609,114392,128378,46224,94183,146692,64885,53057,166340,87507,175737,103620,86453,139082,55149,154607,213979,55483,89872,136966,202404,51557,63794,107720,158240,63765,113684,67793,189666,144259,63854,34007,114323,54256,272996,54146,32926,47908,121384,133238,68263,194364,98002,40770,54488,128247,79588,154496,166781,72245,206257,145271,81533,308823,249324,165792,139175,48201,128912,324061,264209,193480,64705,171218,162562,59904,192545,194442,63655,49496,90557,52763,66981,46549,64577,206831,260674,156933,91065,114714,47671,43632,172307,87052,107176,108338,85303,117643,102169,53217,104343,52483,67671,237827,269645,88770,172697,49695,64393,199888,80669,85510,58608,41059,139360,113645,113621,184001,82405,58701,108428,153539,47668,48541,50111,40353,118816,83896,57477,60737,126827,96170,89495,220156,291446,122018,93277,106534,81280,63842,52448,84698,202056,97350,80017,88462,112811,53562,158284,219210,75430,120239,164439,78867,45604,123313,307439,134864,114706,119558,87169,49096,122643,105825,117816,185576,251827,124148,63771,93814,60252,130564,70443,69399,93165,105434,233643,87234,103447,174143,88025,175743,142753,64816,90189,144194,139002,92965,49276,237558,55972,229819,75728,119685,75958,50605,183449,89183,89056,56311,69734,175663,79684,289312,87273,38316,74721,41811,89500,227863,162762,203007,66052,186783,92941,62950,289435,111672,136910,55093,73307,171629,72226,156172,85908,40719,72876,211142,122390,44236,111300,156224,54416,125538,201243,82260,86657,223945,206448,11822 ...
# --- Note: Note: The graph shows that remote ratio does not have a significant influence on the salary distribution in AI Jobs. ---

# %% [markdown]
# ##### What is the salary distribution vs education required? (ordered by median salary)

# %%
# Plotting the education required vs salary distribution (Ordered by median salary)

education_required_sorted = df_ai_job.groupby("education_required")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='education_required', color='education_required',
          title='Salary Distribution vs Education Required<br><sup>Ordered by median salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'education_required': 'Education Required'},
          category_orders={'education_required': education_required_sorted},
          ticktext=['Associate', 'Bachelor', 'Master', 'PhD'],
          tickvals=['Associate', 'Bachelor', 'Master', 'PhD'],
          legend_labels={'Associate': 'Associate', 'Bachelor': 'Bachelor', 'Master': 'Master', 'PhD': 'PhD'},
          with_tick=True)

print("--- Note: Interestingly, the graph shows that the best-paid education required is a master's degree. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16f6cafe-ea4b-4859-8906-57cdae864848" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16f6cafe-ea4b-4859-8906-57cdae864848")) {                    Plotly.newPlot(                        "16f6cafe-ea4b-4859-8906-57cdae864848",                        [{"alignmentgroup":"True","hovertemplate":"Education Required=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Master","marker":{"color":"#2E91E5"},"name":"Master","notched":false,"offsetgroup":"Master","orientation":"h","showlegend":true,"x":[61895,54624,70640,102557,115047,68760,52167,80979,82083,67488,68624,111381,115376,67607,122831,56427,284486,196942,152118,138945,84797,290199,213287,64261,143149,50303,121180,143246,203198,69487,258637,116012,149053,63860,101054,145355,183484,93211,82209,83226,46995,210249,67708,95796,229098,134300,180764,89115,180252,56585,44130,127478,68595,53960,285880,82051,159643,52027,36734,59357,59198,138212,199039,87871,132056,85037,80307,107321,65191,133565,68857,111502,142301,147732,50749,66150,98694,63711,223296,186565,114225,388754,45129,68001,51736,61808,78751,79556,100354,62606,145098,83381,46591,99604,58899,153376,66601,99818,115634,110858,115976,71134,213785,132585,135102,122593,171375,141385,298418,87006,69827,60097,101978,95186,117568,198743,97175,187668,222757,226519,88878,101624,84728,49641,103692,226973,73669,43707,53707,49234,77545,171813,130454,47965,61352,63273,188034,125153,146076,140113,83663,35782,97749,259184,62692,69418,53116,148848,139122,97771,97370,167210,90291,303636,42279,115496,133372,137181,151385,109757,176838,84450,54457,146370,222869,118402,112606,88916,145141,149673,46335,204346,193865,154077,63832,89120,107828,101302,174571,59027,104307,112261,107490,98449,237830,114392,95469,169198,47386,140497,84288,73556,94446,155622,104981,66992,96225,55320,152846,60829,48427,268001,129638,139082,114575,55149,153207,213979,89872,136668,51557,63794,118833,143010,202935,59833,32926,161576,104278,54120,194364,55870,128595,98002,83080,178494,92213,175244,72245,145271,157394,133327,73640,165792,85604,152753,128912,324061,193480,171218,162562,192545,194442,85110,39252,178695,72300,157364,58108,65456,46549,64577,260674,122140,156933,81612,129423,175418,203407,63098,243973,87052,107176,48616,108338,197389,161971,62406,132548,109131,172093,156162,334614,104343,38483,123571,135653,88770,116638,177931,186582,113645,129639,53959,82330,56321,80269,118816,57477,291446,61729,122018,84845,93842,191731,164834,63842,144518,84698,175790,158284,41740,219210,42732,164439,78867,122274,87169,72092,54500,94764,185576,164931,302848,58841,63771,34317,158302,270901,91654,64590,59969,131769,109449,69399,39958,105434,364635,66172,224686,174143,88025,130884,139002,75890,159770,55972,129026,67449,119685,147780,70130,56311,201525,89198,58700,91777,289312,74721,89500,203007,87707,186783,103040,102678,128119,75782,72226,52538,65473,69013,40719,211142,122390,361541,68035,130445,125538,62174,82260,80733,50634,75856,94561,175527,70893,140451,201318,72876,95250,95182,101245,137532,105092,46498,85954,142410,266476,93956,263686,171699,63018,81157,48540,266949,221670,119356,108379,58188,36240,40062,144386,46475,144440,147573,56533,69961,79221,172750,150823,135560,180474,78059,96760,48306,158635,63645,244496,135021,42507,80482,106727,122715,151875,53136,60749,141332,208210,47803,75735,159718,107810,53572,130323,180089,193391,284013,111609,130148,119598,273838,182542,99539,209331,36974,91293,129743,102189,55317,41569,75031,77498,149846,80171,69318,50892,59023,178756,68724,39127,94480,198321,88938,199683,53780,135740,47715,58685,69092,228323,63608,88152,91939,122921,107422,59376,99872,38835,123071,61820,234686,111499,50962,15 ...
# --- Note: Interestingly, the graph shows that the best-paid education required is a master's degree. ---

# %% [markdown]
# ##### What is the salary distribution vs years experience? (ordered by median salary)

# %%
# Plotting the years experience vs salary distribution (Ordered by median salary)

years_experience_salary_usd_grouped = df_ai_job[['years_experience', 'salary_usd']]
years_experience_salary_usd_grouped['years_experience_grouped'] = years_experience_salary_usd_grouped['years_experience'].apply(
    lambda x: 'Up to 1' if x < 2 else ('2-4' if x < 5 else ('5-9' if x < 10 else '10-19')))

years_experience_salary_usd_sorted = years_experience_salary_usd_grouped.groupby("years_experience_grouped")["salary_usd"].median().sort_values(ascending=False).index.to_list()

plot_box_(years_experience_salary_usd_grouped, x='salary_usd', y='years_experience_grouped', color='years_experience_grouped',
          title='Salary Distribution vs Years Experience<br><sup>Ordered by median salary</sup>',
          labels={'years_experience_grouped': 'Years Experience', 'salary_usd': 'Salary (USD)'},
          category_orders={'years_experience_grouped': years_experience_salary_usd_sorted},
          ticktext=['Up to 1', '2-4', '5-9', '10-19'],
          tickvals=['Up to 1', '2-4', '5-9', '10-19'],
          legend_labels={'Up to 1': 'Up to 1', '2-4': '2-4', '5-9': '5-9', '10-19': '10-19'},
          with_tick=True)

print("--- Note: The graph shows that the years of experience has a positive influence on the salary distribution in AI Jobs. ---")
print("--- Note: The highest median salaries are for the 10-19 years of experience range, followed by the 5-9, 2-4 and Up to 1 ranges. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35e474ab-68bf-4c16-b40a-862bffcca667" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35e474ab-68bf-4c16-b40a-862bffcca667")) {                    Plotly.newPlot(                        "35e474ab-68bf-4c16-b40a-862bffcca667",                        [{"alignmentgroup":"True","hovertemplate":"Years Experience=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10-19","marker":{"color":"#2E91E5"},"name":"10-19","notched":false,"offsetgroup":"10-19","orientation":"h","showlegend":true,"x":[115047,181139,178183,126942,111381,166080,288815,124871,115376,316182,213783,284486,157597,196942,207548,125666,152118,138945,290199,138466,213287,152658,205357,165676,231078,182275,143246,95673,141791,258637,324557,149053,224919,220439,184637,190314,198403,145355,183484,214195,178240,275296,300422,210249,95796,229098,134300,201971,180764,301038,285880,254305,223757,138212,199039,255678,110064,152969,141523,168619,199482,142301,178371,157412,250562,167401,147732,222223,138782,178470,159003,98694,186565,160286,388754,238449,193149,99604,262339,153376,93369,215782,115976,221235,213785,182747,133437,132585,135102,171375,141125,305621,187599,229855,141385,231393,298418,206945,353726,95186,124709,191741,125762,134632,198743,187668,222757,160302,226519,97260,109279,226973,170702,149281,152266,217701,138694,146600,156725,272652,134087,188034,146076,142657,291226,271344,136651,237637,135272,160234,286216,259184,105668,223289,153083,201269,148214,313205,111371,120586,182856,139122,162476,160883,138000,261332,133019,216253,169842,167210,303636,115496,224280,349562,137181,151385,242433,116320,102675,222869,195999,236175,145141,149673,204346,184631,113269,231074,193865,154077,203751,221809,174571,283696,233692,100620,104307,201387,150456,106457,176592,237830,210609,114392,145886,168131,222528,146692,137927,169198,122645,262925,169198,188924,87507,152846,145966,268001,132334,153207,283569,173652,154607,213979,202404,192550,135830,189666,144259,202935,200761,272996,149451,231893,122818,194364,128595,98002,178494,154496,166781,206257,145271,133327,308823,249324,165792,349508,95775,128912,324061,264209,193480,278777,171218,162562,192545,194442,215545,178695,91260,114900,267363,206831,260674,161560,211117,156933,203407,243973,197389,161971,117643,152069,172093,145214,179667,171215,156162,187720,334614,237827,269645,135653,149345,264300,268218,244121,128609,177931,199888,139360,283408,155932,184001,306862,171299,109517,161346,272477,139357,133277,152020,133002,220156,291446,122018,370038,191731,164834,243337,121076,175790,202056,97350,219210,190164,101503,191148,134769,307439,153686,289428,185576,164931,302848,251827,232297,304419,158302,270901,233643,364635,165018,224686,175743,283980,93566,197981,144194,139002,237558,129026,160528,229819,200646,168134,183449,157517,201525,175663,289312,131757,227863,162762,203007,186783,289435,131748,146263,128119,172415,275544,171629,193717,156172,275914,211142,154290,361541,178482,316575,156224,211287,201243,159232,144647,102083,223945,206448,197656,139936,175527,224367,305068,201318,146911,163176,161876,131824,148785,312110,119135,127299,270468,105092,87076,159681,106688,142410,266476,217596,236415,263686,172076,111618,179544,100927,266949,221670,228183,258096,104224,267096,111536,101414,144386,231796,166725,129293,151884,183433,215098,241026,219333,144440,253997,166682,185005,179455,147573,268848,150823,96760,91092,101009,158635,239573,249930,290579,173242,244496,187375,238792,226504,186222,151875,331854,240150,219041,163357,208210,159718,161115,270252,185695,127125,186801,133565,223202,180089,193391,184262,284013,86961,174304,273838,145239,160290,161117,209331,91293,136980,28 ...
# --- Note: The graph shows that the years of experience has a positive influence on the salary distribution in AI Jobs. ---
# --- Note: The highest median salaries are for the 10-19 years of experience range, followed by the 5-9, 2-4 and Up to 1 ranges. ---

# %% [markdown]
# ##### What is the salary distribution vs industry? (ordered by max salary)

# %%
# Plotting the salary distribution vs industry (Ordered by max salary)

industry_sorted = df_ai_job.groupby("industry")["salary_usd"].max().sort_values(ascending=False).index.to_list()

plot_box_(df_ai_job, x='salary_usd', y='industry', color='industry',
          title='Salary Distribution vs Industry<br><sup>Ordered by max salary</sup>',
          labels={'salary_usd': 'Salary (USD)', 'industry': 'Industry'},
          category_orders={'industry': industry_sorted}, height=600)

print("--- Note: Interestingly, the graph shows that retail pays higher wages than the tech sector. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57d91f84-d80f-4070-934e-6c85c0ed70e3" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57d91f84-d80f-4070-934e-6c85c0ed70e3")) {                    Plotly.newPlot(                        "57d91f84-d80f-4070-934e-6c85c0ed70e3",                        [{"alignmentgroup":"True","hovertemplate":"Industry=%{y}\u003cbr\u003eSalary (USD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Retail","marker":{"color":"#2E91E5"},"name":"Retail","notched":false,"offsetgroup":"Retail","orientation":"h","showlegend":true,"x":[82083,67488,113455,71405,134200,290199,95085,61055,65570,64531,94478,125152,149669,110341,122331,52027,120749,119706,80307,81885,151610,222223,52877,186565,160286,115634,77579,46236,95186,160302,107195,170702,77545,271344,105668,62692,70084,130864,53116,182856,224280,50915,92318,242433,150795,195999,112920,52062,231074,86218,89120,55576,107490,237830,46224,73953,166340,89872,121384,111067,92213,133327,60462,54926,215545,65456,267363,63898,184001,63532,51089,40353,71955,133002,89495,61729,93277,370038,81280,52448,49096,89986,50086,87234,165018,224686,174143,175743,62450,129483,131757,289435,123064,73307,275544,72226,361541,68035,51565,206448,70893,72459,95182,106688,77628,179544,48540,108379,65202,58204,36240,61419,53844,116016,47803,39725,136980,125758,199683,121453,38637,171132,38835,255147,50287,72160,61820,82748,78460,65679,116310,119975,53292,87139,55375,56037,204726,77562,82441,163142,156004,124366,85670,163835,56123,56723,90143,46459,71629,76846,113366,113181,119365,352006,251969,165928,136398,64798,154787,90708,49483,308706,91928,86137,169778,123831,101396,130312,80482,148874,125520,87043,102923,142410,146710,186452,100018,90742,64501,96755,91487,48423,75628,108325,50842,41702,37896,67736,130712,47231,65806,112417,66794,252948,93099,74097,132848,76148,73902,57791,127095,182354,101287,79063,100761,103139,109052,108820,120160,84329,68445,272964,111568,49933,47697,158528,143861,131406,41658,128846,89122,287746,110302,237060,212327,193284,212906,66069,197335,272219,161339,118944,179157,151463,182901,160736,161974,60598,97938,235192,80759,160641,49426,140290,99647,52922,104295,113198,178912,92549,238935,198798,87795,48009,65139,179942,155145,79491,66393,70797,89220,68278,83927,187473,43762,333499,50646,93862,254413,162193,90319,215202,147573,147188,42629,66712,80433,142089,68077,103742,165526,89298,68840,74606,63991,101811,80880,62309,166199,56642,96483,152803,102312,170703,40777,74792,93153,98251,117809,123597,82315,193009,139002,163282,137662,62288,80252,181837,299049,94837,47595,205645,214903,67720,64559,248290,47575,141895,133016,132671,33854,98392,92276,48414,65615,75242,334774,59643,150003,84328,89037,160641,94267,52519,54910,137612,138492,122025,34190,80121,100638,159121,215355,72360,65507,139402,150930,94160,216468,163410,53083,98606,76318,172592,281427,111678,78878,72127,95464,104657,89223,136611,310949,98023,123850,72609,53702,97811,100665,119828,84429,95486,263099,113125,56512,235764,145481,70390,177967,98089,124236,55567,144445,88262,50261,81054,188552,95063,105516,124113,112981,214097,87897,126730,89600,121439,53994,148781,66015,146198,94472,352707,201159,72332,101372,96038,45661,230984,57312,66282,205134,119954,78105,100362,62094,91631,124858,153576,146170,296033,44343,55981,141523,34357,155722,75390,184181,68757,155652,120722,73513,179546,92005,100926,52976,102177,105817,83404,194251,65984,54601,90293,56717,53554,70508,58808,135648,73179,100209,268707,105658,36359,71358,97667,211093,128823,65625,120348,101914,131893,110545,187069,65435,146929,85579,72406,328260,59767,90718,142391,171409,64384,63717,99007,155281,76629,52575,97538,42188,138403,86408,115052,57169,95822,38781,105571,111195, ...
# --- Note: Interestingly, the graph shows that retail pays higher wages than the tech sector. ---

# %% [markdown]
# ##### What are the top 5 skills valued in the top 5 paying jobs sorted by median?

# %%
# Plotting the top 5 skills valued in the top 5 paying jobs sorted by

job_titles_sorted_5 = df_ai_job.groupby("job_title")["salary_usd"].median().sort_values(ascending=False).index.to_list()[:5]

df_ai_job_top5 = df_ai_job[df_ai_job['job_title'].isin(job_titles_sorted_5)][['job_title', 'salary_usd', 'required_skills']]

df_ai_job_top5['required_skills'] = df_ai_job_top5['required_skills'].str.split(', ')
df_ai_job_top5 = df_ai_job_top5.explode('required_skills')

for job_title in job_titles_sorted_5:
    skills = df_ai_job_top5[df_ai_job_top5['job_title'] == job_title]
    skills_counts = skills['required_skills'].value_counts().reset_index()
    skills_counts.columns = ['skill', 'count']
    skills_counts = skills_counts[:5]

    plot_bar(df=skills_counts, x='count', y='skill',
         title=f'[{job_title}] Required Skills Frequency in AI Jobs',
         labels={'skill': 'Skill', 'count': 'Count'},
         color='skill', orientation='h', height=300,
         hovertemplate='<b>%{y}</b><br>Count=%{x}<extra></extra>')

    print("---")

print("--- Note: The top 5 AI job titles and their top 5 required skills are shown in the graphs above. ---")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc0d0a63-8e80-4695-a694-29affdcf06e1" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc0d0a63-8e80-4695-a694-29affdcf06e1")) {                    Plotly.newPlot(                        "cc0d0a63-8e80-4695-a694-29affdcf06e1",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[233],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[163],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kubernetes","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[159],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[156],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scala","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Scala","offsetgroup":"Scala","orientation":"h","showlegend":true,"textposition":"auto","x":[145],"xaxis":"x","y":["Scala"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{" ...
# ---
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f93a0ff3-7e53-4803-8820-76e1abc601d1" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f93a0ff3-7e53-4803-8820-76e1abc601d1")) {                    Plotly.newPlot(                        "f93a0ff3-7e53-4803-8820-76e1abc601d1",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[209],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[163],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[154],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kubernetes","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[147],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scala","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Scala","offsetgroup":"Scala","orientation":"h","showlegend":true,"textposition":"auto","x":[145],"xaxis":"x","y":["Scala"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{" ...
# ---
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86a36202-0784-42f8-b9fa-fb3624c00686" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86a36202-0784-42f8-b9fa-fb3624c00686")) {                    Plotly.newPlot(                        "86a36202-0784-42f8-b9fa-fb3624c00686",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[192],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[161],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PyTorch","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"PyTorch","offsetgroup":"PyTorch","orientation":"h","showlegend":true,"textposition":"auto","x":[151],"xaxis":"x","y":["PyTorch"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[148],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kubernetes","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[143],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatma ...
# ---
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8846ba1d-d1b4-4add-b164-6f66575cc7a2" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8846ba1d-d1b4-4add-b164-6f66575cc7a2")) {                    Plotly.newPlot(                        "8846ba1d-d1b4-4add-b164-6f66575cc7a2",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[243],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[183],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scala","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Scala","offsetgroup":"Scala","orientation":"h","showlegend":true,"textposition":"auto","x":[158],"xaxis":"x","y":["Scala"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[156],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kubernetes","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[155],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{" ...
# ---
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d8d6aa38-8fd9-4695-8c33-d500b58d9a41" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8d6aa38-8fd9-4695-8c33-d500b58d9a41")) {                    Plotly.newPlot(                        "d8d6aa38-8fd9-4695-8c33-d500b58d9a41",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[243],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"SQL","offsetgroup":"SQL","orientation":"h","showlegend":true,"textposition":"auto","x":[162],"xaxis":"x","y":["SQL"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TensorFlow","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientation":"h","showlegend":true,"textposition":"auto","x":[158],"xaxis":"x","y":["TensorFlow"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Git","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Git","offsetgroup":"Git","orientation":"h","showlegend":true,"textposition":"auto","x":[149],"xaxis":"x","y":["Git"],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Linux","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black","width":1.5}},"name":"Linux","offsetgroup":"Linux","orientation":"h","showlegend":true,"textposition":"auto","x":[136],"xaxis":"x","y":["Linux"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar" ...
# ---
# --- Note: The top 5 AI job titles and their top 5 required skills are shown in the graphs above. ---

# %% [markdown]
# #### Conclusion
# After all these graphs, we hope you can plan your career in AI jobs by looking at the distribution and frequency of different columns.
# I think it is pretty clear that you need to start learning Python and SQL and as you gain experience and time, keep in mind that bigger companies pay better salaries.

# %% [markdown]
# #### Suggestion
# You can explore other questions to increase your awareness, such as:\
# What is the distribution of benefits scores vs company size?\
# What is the distribution of employment type vs experience level?\
# What is the distribution of remote ratio vs company location?
